# %% [markdown]
# ### 1、Import tensorflow and use tensorflow to define a constant.

# %%
import tensorflow as tf

# %%
hello = tf.constant("Hello, TF")

# %% [markdown]
# ### 2、Use tensorflow to print 'Welcome to Huawei'.

# %%
session = tf.compat.v1.Session()
tf.compat.v1.disable_eager_execution()
hello = tf.constant('Welcome to Huawei')
result = session.run(hello)
print(result)
session.close()
# Out:
# b'Welcome to Huawei'

# %% [markdown]
# ### 3、Use tensorflow to define two numeric constants,then calculate them and print the result.

# %%
z = tf.constant(151)
x = tf.constant(9)

result = z * x
with tf.compat.v1.Session() as sess:
    print(sess.run(result))
sess.close()
# Out:
# 1359

# %% [markdown]
# ### 4、Randomly generate two matrices using tensorflow, calculate and print the result of their multiplication.

# %%
sess = tf.compat.v1.InteractiveSession()
A = tf.Variable(tf.compat.v1.random_normal([3,4],mean=1.0, stddev=1.0))
B = tf.Variable(tf.compat.v1.random_normal([4,3],mean=1.0, stddev=1.0))
tf.compat.v1.global_variables_initializer().run()

result = tf.matmul(A, B)
print(result.eval())
# Out:
# [[ 7.2318654  -0.04632032  7.2239285 ]
#  [ 2.5088463   2.6478477  -0.1931045 ]
#  [ 2.469889   -1.477498    4.2000384 ]]

# %% [markdown]
# ### 5、Try to use your own handwriting number to do image recognition

# %%
import numpy as np 
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
learn = tf.contrib.learn 
tf.logging.set_verbosity(tf.logging.ERROR)
mnist = input_data.read_data_sets("data\\MNIST_data\\")
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting data\MNIST_data\/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting data\MNIST_data\/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting data\MNIST_data\/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting data\MNIST_data\/t10k-labels-idx1-ubyte.gz

# %%
data = mnist.train.images 
labels = np.asarray(mnist.train.labels, dtype = np.int32) 
test_data = mnist.test.images 
test_labels = np.asarray(mnist.test.labels, dtype = np.int32) 
  
max_examples = 10000
data = data[:max_examples] 
labels = labels[:max_examples]

# %%
def display(i): 
    img = test_data[i] 
    plt.title('label : {}'.format(test_labels[i])) 
    plt.imshow(img.reshape((28, 28))) 

# img in tf is 28 by 28 px 
# fitting linear classifier 
feature_columns = learn.infer_real_valued_columns_from_input(data) 
classifier = learn.LinearClassifier(n_classes = 10,  
                                    feature_columns = feature_columns)
classifier.fit(data, labels, batch_size = 100, steps = 1000)
# Out:
# LinearClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x7fef4a172b90>, 'feature_columns': [_RealValuedColumn(column_name='', dimension=784, default_value=None, dtype=tf.float32, normalizer=None)], 'optimizer': None, 'gradient_clip_norm': None, 'joint_weights': False})

# %%
# Evaluate accuracy 
classifier.evaluate(test_data, test_labels) 
print(classifier.evaluate(test_data, test_labels)["accuracy"]) 
  
prediction = classifier.predict(np.array([test_data[11]],  
                                         dtype=float),  
                                         as_iterable=False) 
print("prediction : {}, label : {}".format(prediction,  
      test_labels[11]) ) 
  
if prediction == test_labels[11]: 
     display(11)
# Out:
# 0.9137
# prediction : [6], label : 6
